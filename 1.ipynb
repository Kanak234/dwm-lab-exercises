# %%
import pandas as pd

# %%
data=['kanak', 'john', 'jane', 'doe', 'smith', 'jones', 'brown', 'davis', 'miller', 'wilson']
df1 = pd.DataFrame(data, columns=['friends'])
df1.head()
# Out:
#   friends
# 0   kanak
# 1    john
# 2    jane
# 3     doe
# 4   smith
